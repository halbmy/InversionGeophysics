# %% [markdown]
# ## Linear Regression
#
# Task: do a linear regression
#
# Our data are described by a linear function $ax+b$ plus some noise $n$
#
# $$d_i = a x_i + b + n_i$$
#
# $d_i$ are the measured values for some measuring point $x_i$.
#
# The coefficiencts $a$ and $b$ are the same for all data $d_i$ and subsumed in a model vector
#
# $${\bf m}=\begin{bmatrix}a\\b\end{bmatrix} = \begin{bmatrix}m_1\\m_2\end{bmatrix}$$

# %% [markdown]
# The forward operator is linear with respect to m and can be written as ${\bf A}{\bf m}={\bf d}$ with
# $$
# {\bf A}=\begin{bmatrix}
# x_1 & 1\\
# x_2 & 1\\
# \ldots & \ldots \\
# x_D & 1
# \end{bmatrix}$$

# %% [markdown]
# **Task**: Write a function that creates a matrix for a set of given $x$ values. Create one for a given $x$ vector and plot some examples.

# %%
function LinRegMatrix(x)
    """Create Linear Regression matrix."""
    A = ones(length(x), 2)
    A[:, 1] = x[:]
    return A
end
# Out:
# LinRegMatrix (generic function with 1 method)

# %%
range(start=0, stop=3, step=0.1)
# Out:
# 0.0:0.1:3.0

# %%
using PyPlot
using Statistics
# x = (0:0.1:3.0) 
x = range(start=0, stop=3, step=0.1)
x[end] = 4
error = 0.1
A = LinRegMatrix(x)
d = A * [0.5; -0.5] + randn(length(x)) .* error
# determine least-squares solution
m = A \ d[:]
print(m)
plot(x, d, "b+")
plot(x, A*m, "r-")
grid()
# Out:
# CanonicalIndexError: setindex! not defined for StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}
#
#
#
# Stacktrace:
#
#  [1] error_if_canonical_setindex(::IndexLinear, A::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, ::Int64)
#
#    @ Base .\abstractarray.jl:1421
#
#  [2] setindex!(A::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, v::Int64, I::Int64)
#
#    @ Base .\abstractarray.jl:1412
#
#  [3] top-level scope
#
#    @ c:\Users\Thomas Guenther\lehre\Inv\InvGy\notebooks\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W5sZmlsZQ==.jl:5

# %%
residual = A * m - d[:]
print("mean=", mean(residual), " std=", std(residual))
eresidual = residual / error
print("mean=", mean(eresidual), " std=", std(eresidual))
hist(eresidual, bins=20);
# Out:
# UndefVarError: `A` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ c:\Users\Thomas Guenther\lehre\Inv\InvGy\notebooks\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W6sZmlsZQ==.jl:1

# %% [markdown]
# ### Lessons to be learned
# 1. The least-squares inversion minimizing the L2 norm is strongly connected to Gaussian statistics.
# 1. The error-weighted residual should (for large data numbers) show a Gaussian normal distribution (mean value of 0 and standard deviation of 1).
# 1. The misfit function should not show any systematics.

# %% [markdown]
# ## Tasks for homework
# 1. Test with different values for the model and plot also the misfit $d-Am$
# 1. Increase the error level and look at the residual statistics.
# 1. Decrease or increase the number of measurements and watch statistics.
# 1. Test the same with common random noise instead of Gaussian noise.
# 1. Extend the matrix function to an arbitrary polynomial degree $P$
#
# $$ y_i = \sum\limits_{j=0}^P a_{ij} x^j $$
#
# (note the reversed order of coefficients)
#
# 1. Repeat the inversion by fitting a third-order polynomial.
# 1. Compute the singular value decomposition for different polynomial degrees.

# %%
Ainv = inv(A' * A) * A'
RM = Ainv * A
display(RM)
RD = A * Ainv
matshow(RD)
clim([-0.2, 0.2])
set_cmap("bwr")
colorbar()
# Out:
# UndefVarError: `A` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ c:\Users\Thomas Guenther\lehre\Inv\InvGy\notebooks\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X12sZmlsZQ==.jl:1

# %%
using LinearAlgebra
rd = diag(RD)
display(sum(rd))
plot(x, rd, "x-")
# Out:
# UndefVarError: `RD` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ c:\Users\Thomas Guenther\lehre\Inv\InvGy\notebooks\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X13sZmlsZQ==.jl:2

# %% [markdown]
# **Lessons learned**
#
# * the data importance matrix is symmetric
# * the total importance is 2 (number of model parameters)
# * the importance (influence on result) is growing towards the end members
# * there is a positive correlation between neighboring data

# %%
plot(x, RD[1, :], "x-");
# Out:
# UndefVarError: `RD` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ c:\Users\Thomas Guenther\lehre\Inv\InvGy\notebooks\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:1

# %% [markdown]
# **Tasks**:
#
# * switch to a non-equidistant discretization
# * how does the data importance matrix change?
# * introduce an error vector with a single higher and a single lower value
# * how do the data importances change for these?

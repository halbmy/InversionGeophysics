# %%
using LinearAlgebra

# %%
G = [1 2 0;0 0 1]
display(G)
d = [2;3]
# Out:
# 2×3 Matrix{Int64}:
#  1  2  0
#  0  0  1
# 2-element Vector{Int64}:
#  2
#  3

# %%
G\d
# Out:
# 3-element Vector{Float64}:
#  0.39999999999999997
#  0.7999999999999999
#  3.0

# %%
m = G' * inv(G*G') * d
# Out:
# 3-element Vector{Float64}:
#  0.4
#  0.8
#  3.0
